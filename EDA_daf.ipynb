# %%
import pandas as pd

data = pd.read_csv('competition_data.csv')
submission = pd.read_csv('submission.csv')
submission_aux = pd.read_csv('submission.csv')

# %%
data = data.drop(columns=['username', 'conn_country', 'user_agent_decrypted'])
submission = submission.drop(columns=['username', 'conn_country', 'user_agent_decrypted'])

# %%
# del timestamp, solo nos interesa distinguir hora, el dia de la semana, el mes y el año

data['ts'] = pd.to_datetime(data['ts'])
submission['ts'] = pd.to_datetime(submission['ts'])

# Extraer la hora
data['hour'] = data['ts'].dt.hour
submission['hour'] = submission['ts'].dt.hour

# Extraer el día de la semana (0 es lunes, 6 es domingo)
data['day_of_week'] = data['ts'].dt.dayofweek
submission['day_of_week'] = submission['ts'].dt.dayofweek

# Extraer el mes
data['month'] = data['ts'].dt.month
submission['month'] = submission['ts'].dt.month

# Extraer el año
data['year'] = data['ts'].dt.year - 2000
submission['year'] = submission['ts'].dt.year - 2000

# %%
# del dispositivo, solo queremos saber si se reprodujo en celular (iphone) o no
data['is_iphone'] = data['platform'].apply(lambda x: 1 if ('ios' in x or 'iOS' in x) else 0)
submission['is_iphone'] = submission['platform'].apply(lambda x: 1 if ('ios' in x or 'iOS' in x) else 0)

# dropeamos platform
data = data.drop(columns=['platform'])
submission = submission.drop(columns=['platform'])

# %%
data
# Out:
#         Unnamed: 0                        ts  \
# 0           110163 2018-03-11 05:05:45+00:00
# 1            66026 2023-06-05 10:42:33+00:00
# 2           116790 2018-07-01 02:04:51+00:00
# 3            18431 2019-09-08 04:58:07+00:00
# 4            82941 2017-07-13 18:13:52+00:00
# ...            ...                       ...
# 100139       78756 2017-04-06 20:31:14+00:00
# 100140       12585 2021-11-03 21:06:07+00:00
# 100141       93960 2022-01-14 01:13:42+00:00
# 100142       74339 2024-05-01 17:51:16+00:00
# 100143       23611 2019-12-07 21:59:47+00:00
#
#                                master_metadata_track_name  \
# 0                                             Crazy For U
# 1                      Nada Personal - Remasterizado 2007
# 2                                              Good Times
# 3                                           Verano del 92
# 4                                               Simpatico
# ...                                                   ...
# 100139                                 Losing My Religion
# 100140                             Cerca De La Revolucion
# 100141            A Los Jóvenes De Ayer - Remastered 2012
# 100142                                       heat not hot
# 100143  Casi Nunca Lo Ves (En Vivo) (feat. Ciro y Los ...
#
#        master_metadata_album_artist_name  \
# 0                          Big Time Rush
# 1                            Soda Stereo
# 2                                   CHIC
# 3                             Los Piojos
# 4                              Ekko Park
# ...                                  ...
# 100139                            R.E.M.
# 100140                     Charly García
# 100141                        Serú Girán
# 100142                         Serengeti
# 100143                       Los Pericos
#
#              master_metadata_album_album_name  \
# 0                                    24/seven
# 1                Me Verás Volver (Hits & Más)
# 2                                      Risqué
# 3                                    3er Arco
# 4                                   Simpatico
# ...                                       ...
# 100139  In Time: The Best Of R.E.M. 1988-2003
# 100140                              Piano Bar
# 100141                              Bicicleta
# 100142                           heat not hot
# 100143                             3000 Vivos
#
#                            spotify_track_uri reason_start  shuffle  TARGET  \
# 0       spotify:track:3jFfr89lnSmb4QBtfG8JBP     clickrow    False   False
# 1       spotify:track:09TTeexnlKewZdjOak2sV2    trackdone     True   False
# 2       spotify:track:0G3fbPbE1vGeABDEZF0jeG    trackdone     True    True
# 3       spotify:track:1NXvuBAq48QrxRFQZVmORQ    trackdone    False    True
# 4       spotify:track:2gYJY0sIx1ErgTIha2nPRg    trackdone     True   False
# ...                                      ...          ...      ...     ...
# 100139  spotify:track:12axV6NUqaYH3yFUWwArzr    trackdone     True   False
# 100140  spotify:track:66grIvFLGrI4tNhggO2DAd    trackdone     True   False
# 100141  spotify:track:6YAl320SfxLO4rVIZTFKqG    trackdone     True   False
# 100142  spotify:track:0rKLO1hXpmoIthQgJKoczN    trackdone     True   False
# 100143  spotify:track:4EbfeFf88tna6YcInp1ugJ       fwdbtn     True    True
#
#         hour  day_of_week  month  year  is_iphone
# 0          5            6      3    18          1
# 1         10            0      6    23          1
# 2          2            6      7    18          1
# 3          4            6      9    19          1
# 4         18            3      7    17          1
# ...      ...          ...    ...   ...        ...
# 100139    20            3      4    17          1
# 100140    21            2     11    21          1
# 100141     1            4      1    22          1
# 100142    17            2      5    24          1
# 100143    21            5     12    19          0
#
# [100144 rows x 14 columns]

# %%
correlacion = data['TARGET'].corr(data['is_iphone'])
print(f"Correlación: {correlacion:.4f}")
# Out:
# Correlación: -0.1861

# %%
# Aplicar One-Hot Encoding a razon de reproduccion
data_encoded = pd.get_dummies(data['reason_start'], prefix='reason', dummy_na=False)

# Concatenar el DataFrame original con el nuevo DataFrame de variables codificadas
data = pd.concat([data, data_encoded], axis=1)

# Dropear la columna original
data = data.drop(columns=['reason_start'])
data
# Out:
#         Unnamed: 0                        ts  \
# 0           110163 2018-03-11 05:05:45+00:00
# 1            66026 2023-06-05 10:42:33+00:00
# 2           116790 2018-07-01 02:04:51+00:00
# 3            18431 2019-09-08 04:58:07+00:00
# 4            82941 2017-07-13 18:13:52+00:00
# ...            ...                       ...
# 100139       78756 2017-04-06 20:31:14+00:00
# 100140       12585 2021-11-03 21:06:07+00:00
# 100141       93960 2022-01-14 01:13:42+00:00
# 100142       74339 2024-05-01 17:51:16+00:00
# 100143       23611 2019-12-07 21:59:47+00:00
#
#                                master_metadata_track_name  \
# 0                                             Crazy For U
# 1                      Nada Personal - Remasterizado 2007
# 2                                              Good Times
# 3                                           Verano del 92
# 4                                               Simpatico
# ...                                                   ...
# 100139                                 Losing My Religion
# 100140                             Cerca De La Revolucion
# 100141            A Los Jóvenes De Ayer - Remastered 2012
# 100142                                       heat not hot
# 100143  Casi Nunca Lo Ves (En Vivo) (feat. Ciro y Los ...
#
#        master_metadata_album_artist_name  \
# 0                          Big Time Rush
# 1                            Soda Stereo
# 2                                   CHIC
# 3                             Los Piojos
# 4                              Ekko Park
# ...                                  ...
# 100139                            R.E.M.
# 100140                     Charly García
# 100141                        Serú Girán
# 100142                         Serengeti
# 100143                       Los Pericos
#
#              master_metadata_album_album_name  \
# 0                                    24/seven
# 1                Me Verás Volver (Hits & Más)
# 2                                      Risqué
# 3                                    3er Arco
# 4                                   Simpatico
# ...                                       ...
# 100139  In Time: The Best Of R.E.M. 1988-2003
# 100140                              Piano Bar
# 100141                              Bicicleta
# 100142                           heat not hot
# 100143                             3000 Vivos
#
#                            spotify_track_uri  shuffle  TARGET  hour  \
# 0       spotify:track:3jFfr89lnSmb4QBtfG8JBP    False   False     5
# 1       spotify:track:09TTeexnlKewZdjOak2sV2     True   False    10
# 2       spotify:track:0G3fbPbE1vGeABDEZF0jeG     True    True     2
# 3       spotify:track:1NXvuBAq48QrxRFQZVmORQ    False    True     4
# 4       spotify:track:2gYJY0sIx1ErgTIha2nPRg     True   False    18
# ...                                      ...      ...     ...   ...
# 100139  spotify:track:12axV6NUqaYH3yFUWwArzr     True   False    20
# 100140  spotify:track:66grIvFLGrI4tNhggO2DAd     True   False    21
# 100141  spotify:track:6YAl320SfxLO4rVIZTFKqG     True   False     1
# 100142  spotify:track:0rKLO1hXpmoIthQgJKoczN     True   False    17
# 100143  spotify:track:4EbfeFf88tna6YcInp1ugJ     True    True    21
#
#         day_of_week  ...  is_iphone  reason_appload  reason_backbtn  \
# 0                 6  ...          1           False           False
# 1                 0  ...          1           False           False
# 2                 6  ...          1           False           False
# 3                 6  ...          1           False           False
# 4                 3  ...          1           False           False
# ...             ...  ...        ...             ...             ...
# 100139            3  ...          1           False           False
# 100140            2  ...          1           False           False
# 100141            4  ...          1           False           False
# 100142            2  ...          1           False           False
# 100143            5  ...          0           False           False
#
#         reason_clickrow  reason_fwdbtn  reason_playbtn  reason_remote  \
# 0                  True          False           False          False
# 1                 False          False           False          False
# 2                 False          False           False          False
# 3                 False          False           False          False
# 4                 False          False           False          False
# ...                 ...            ...             ...            ...
# 100139            False          False           False          False
# 100140            False          False           False          False
# 100141            False          False           False          False
# 100142            False          False           False          False
# 100143            False           True           False          False
#
#         reason_trackdone  reason_trackerror  reason_unknown
# 0                  False              False           False
# 1                   True              False           False
# 2                   True              False           False
# 3                   True              False           False
# 4                   True              False           False
# ...                  ...                ...             ...
# 100139              True              False           False
# 100140              True              False           False
# 100141              True              False           False
# 100142              True              False           False
# 100143             False              False           False
#
# [100144 rows x 22 columns]

# %%
for col in data_encoded.columns:
    correlacion = data['TARGET'].corr(data[col])
    print(f"Correlación {col}: {correlacion:.4f}")
# Out:
# Correlación reason_appload: -0.0194
# Correlación reason_backbtn: 0.0407
# Correlación reason_clickrow: -0.0676
# Correlación reason_fwdbtn: 0.3944
# Correlación reason_playbtn: 0.1219
# Correlación reason_remote: -0.0207
# Correlación reason_trackdone: -0.4225
# Correlación reason_trackerror: 0.0107
# Correlación reason_unknown: -0.0318

# %%
for col in ['hour', 'day_of_week', 'month', 'year']:
    correlacion = data['TARGET'].corr(data[col])
    print(f"Correlación {col}: {correlacion:.4f}")
# Out:
# Correlación hour: 0.1421
# Correlación day_of_week: 0.0133
# Correlación month: 0.0430
# Correlación year: 0.1624

# %%
data = data.sort_values(by='ts')
def calculate_fwdbtn_seguidos(df):
    # Inicializamos la columna en 0
    df['fwdbtn_seguidos'] = 0
    
    # Iteramos desde la segunda fila
    for i in range(0, len(df)):
        if data.at[i, 'reason_fwdbtn'] == 1:
            # Si la razón es 1, sumamos 1 a la columna fwdbtn_seguidos de la fila actual
            df.at[i, 'fwdbtn_seguidos'] = df.at[i-1, 'fwdbtn_seguidos'] + 1

calculate_fwdbtn_seguidos(data)

# %%
data['fwdbtn_seguidos'].quantile(0.9)
# Out:
# np.float64(2.0)

# %%
def calculate_fwdbtn_spree(df):
    # Inicializamos la columna en 0
    df['fwdbtn_spree'] = 0
    
    # Iteramos desde la segunda fila
    for i in range(0, len(df)):
        if data.at[i, 'fwdbtn_seguidos'] > 1:
            df.at[i, 'fwdbtn_spree'] = 1
calculate_fwdbtn_spree(data)

# %%
data
# Out:
#        Unnamed: 0                        ts  \
# 98291       74917 2014-06-27 18:01:16+00:00
# 58819       74918 2014-06-29 20:10:10+00:00
# 57761       74919 2014-06-29 20:10:54+00:00
# 62907       74920 2014-06-29 20:11:16+00:00
# 17525       74921 2014-09-04 21:46:24+00:00
# ...           ...                       ...
# 78701       74911 2024-05-23 17:24:56+00:00
# 83415       74912 2024-05-23 17:28:33+00:00
# 99058       74913 2024-05-23 23:44:01+00:00
# 1772        74914 2024-05-23 23:50:25+00:00
# 21069       74915 2024-05-23 23:56:20+00:00
#
#                   master_metadata_track_name  \
# 98291                         Algo Demencial
# 58819                        Iron Man - Live
# 57761                       Sultans Of Swing
# 62907                          Fortunate Son
# 17525  Comptine d'un autre été, l'après-midi
# ...                                      ...
# 78701                       The Tide Is High
# 83415             The Less I Know The Better
# 99058                           Pink + White
# 1772                     Still Got The Blues
# 21069                              The Loner
#
#       master_metadata_album_artist_name master_metadata_album_album_name  \
# 98291                       Los Tipitos                             Push
# 58819                     Black Sabbath                       Past Lives
# 57761                      Dire Straits                     Dire Straits
# 62907      Creedence Clearwater Revival          Willy And The Poor Boys
# 17525                      Yann Tiersen           Amelie from Montmartre
# ...                                 ...                              ...
# 78701                           Blondie                    Atomic/Atomix
# 83415                       Tame Impala                         Currents
# 99058                       Frank Ocean                           Blonde
# 1772                         Gary Moore              Still Got The Blues
# 21069                        Gary Moore                    Wild Frontier
#
#                           spotify_track_uri  shuffle  TARGET  hour  \
# 98291  spotify:track:0rqD0zvqI4GrvyUxyQ7Ij3     True    True    18
# 58819  spotify:track:1XtZ3GROvmy4JrT6uMvsD8    False    True    20
# 57761  spotify:track:3LTMnFa0hhwisyq6ILahyj    False    True    20
# 62907  spotify:track:7I2lPuuiOkpKtZlhr4zUpT    False    True    20
# 17525  spotify:track:2AkcjsKlRbIBYGAgpQVFii    False    True    21
# ...                                     ...      ...     ...   ...
# 78701  spotify:track:52Rp3xBJFYYdmpgzDy0Quf     True   False    17
# 83415  spotify:track:6K4t31amVTZDgR3sKmwUJJ     True   False    17
# 99058  spotify:track:3xKsf9qdS1CyvXSMEid6g8     True   False    23
# 1772   spotify:track:0DnGfA1r8pAssJCuq4ojla     True   False    23
# 21069  spotify:track:5WQC3PGajELM3QpHWIsbQg     True   False    23
#
#        day_of_week  ...  reason_backbtn  reason_clickrow  reason_fwdbtn  \
# 98291            4  ...           False            False           True
# 58819            6  ...           False            False          False
# 57761            6  ...           False            False           True
# 62907            6  ...           False            False           True
# 17525            3  ...           False            False          False
# ...            ...  ...             ...              ...            ...
# 78701            3  ...           False            False          False
# 83415            3  ...           False            False          False
# 99058            3  ...           False            False          False
# 1772             3  ...           False             True          False
# 21069            3  ...           False            False          False
#
#        reason_playbtn  reason_remote  reason_trackdone  reason_trackerror  \
# 98291           False          False             False              False
# 58819           False          False             False              False
# 57761           False          False             False              False
# 62907           False          False             False              False
# 17525           False          False             False              False
# ...               ...            ...               ...                ...
# 78701           False          False              True              False
# 83415           False          False              True              False
# 99058           False          False              True              False
# 1772            False          False             False              False
# 21069           False          False              True              False
#
#        reason_unknown  fwdbtn_seguidos  fwdbtn_spree
# 98291           False                1             0
# 58819           False                0             0
# 57761           False                1             0
# 62907           False                2             1
# 17525           False                0             0
# ...               ...              ...           ...
# 78701           False                0             0
# 83415           False                0             0
# 99058           False                0             0
# 1772            False                0             0
# 21069           False                0             0
#
# [100144 rows x 24 columns]

# %%
correlacion = data['TARGET'].corr(data['fwdbtn_spree'])
print(f"Correlación: {correlacion:.4f}")
# Out:
# Correlación: 0.2107

# %%
def calculate_trackdone_seguidos(df):
    # Inicializamos la columna en 0
    df['trackdone_seguidos'] = 0

    for i in range(0, len(df)):
        if data.at[i, 'reason_trackdone'] == 1:
            # Si la razón es 1, sumamos 1 a la columna fwdbtn_seguidos de la fila actual
            df.at[i, 'trackdone_seguidos'] = df.at[i-1, 'trackdone_seguidos'] + 1

calculate_trackdone_seguidos(data)

def calculate_fwdbtn_spree(df):
    # Inicializamos la columna en 0
    df['trackdone_spree'] = 0
    
    # Iteramos desde la segunda fila
    for i in range(0, len(df)):
        if data.at[i, 'trackdone_seguidos'] > 1:
            df.at[i, 'trackdone_spree'] = 1
calculate_fwdbtn_spree(data)

# %%
data
# Out:
#        Unnamed: 0                        ts  \
# 98291       74917 2014-06-27 18:01:16+00:00
# 58819       74918 2014-06-29 20:10:10+00:00
# 57761       74919 2014-06-29 20:10:54+00:00
# 62907       74920 2014-06-29 20:11:16+00:00
# 17525       74921 2014-09-04 21:46:24+00:00
# ...           ...                       ...
# 78701       74911 2024-05-23 17:24:56+00:00
# 83415       74912 2024-05-23 17:28:33+00:00
# 99058       74913 2024-05-23 23:44:01+00:00
# 1772        74914 2024-05-23 23:50:25+00:00
# 21069       74915 2024-05-23 23:56:20+00:00
#
#                   master_metadata_track_name  \
# 98291                         Algo Demencial
# 58819                        Iron Man - Live
# 57761                       Sultans Of Swing
# 62907                          Fortunate Son
# 17525  Comptine d'un autre été, l'après-midi
# ...                                      ...
# 78701                       The Tide Is High
# 83415             The Less I Know The Better
# 99058                           Pink + White
# 1772                     Still Got The Blues
# 21069                              The Loner
#
#       master_metadata_album_artist_name master_metadata_album_album_name  \
# 98291                       Los Tipitos                             Push
# 58819                     Black Sabbath                       Past Lives
# 57761                      Dire Straits                     Dire Straits
# 62907      Creedence Clearwater Revival          Willy And The Poor Boys
# 17525                      Yann Tiersen           Amelie from Montmartre
# ...                                 ...                              ...
# 78701                           Blondie                    Atomic/Atomix
# 83415                       Tame Impala                         Currents
# 99058                       Frank Ocean                           Blonde
# 1772                         Gary Moore              Still Got The Blues
# 21069                        Gary Moore                    Wild Frontier
#
#                           spotify_track_uri  shuffle  TARGET  hour  \
# 98291  spotify:track:0rqD0zvqI4GrvyUxyQ7Ij3     True    True    18
# 58819  spotify:track:1XtZ3GROvmy4JrT6uMvsD8    False    True    20
# 57761  spotify:track:3LTMnFa0hhwisyq6ILahyj    False    True    20
# 62907  spotify:track:7I2lPuuiOkpKtZlhr4zUpT    False    True    20
# 17525  spotify:track:2AkcjsKlRbIBYGAgpQVFii    False    True    21
# ...                                     ...      ...     ...   ...
# 78701  spotify:track:52Rp3xBJFYYdmpgzDy0Quf     True   False    17
# 83415  spotify:track:6K4t31amVTZDgR3sKmwUJJ     True   False    17
# 99058  spotify:track:3xKsf9qdS1CyvXSMEid6g8     True   False    23
# 1772   spotify:track:0DnGfA1r8pAssJCuq4ojla     True   False    23
# 21069  spotify:track:5WQC3PGajELM3QpHWIsbQg     True   False    23
#
#        day_of_week  ...  reason_fwdbtn  reason_playbtn  reason_remote  \
# 98291            4  ...           True           False          False
# 58819            6  ...          False           False          False
# 57761            6  ...           True           False          False
# 62907            6  ...           True           False          False
# 17525            3  ...          False           False          False
# ...            ...  ...            ...             ...            ...
# 78701            3  ...          False           False          False
# 83415            3  ...          False           False          False
# 99058            3  ...          False           False          False
# 1772             3  ...          False           False          False
# 21069            3  ...          False           False          False
#
#        reason_trackdone  reason_trackerror  reason_unknown  fwdbtn_seguidos  \
# 98291             False              False           False                1
# 58819             False              False           False                0
# 57761             False              False           False                1
# 62907             False              False           False                2
# 17525             False              False           False                0
# ...                 ...                ...             ...              ...
# 78701              True              False           False                0
# 83415              True              False           False                0
# 99058              True              False           False                0
# 1772              False              False           False                0
# 21069              True              False           False                0
#
#        fwdbtn_spree  trackdone_seguidos  trackdone_spree
# 98291             0                   0                0
# 58819             0                   0                0
# 57761             0                   0                0
# 62907             1                   0                0
# 17525             0                   0                0
# ...             ...                 ...              ...
# 78701             0                   2                1
# 83415             0                   1                0
# 99058             0                   1                0
# 1772              0                   0                0
# 21069             0                   5                1
#
# [100144 rows x 26 columns]

# %%
correlacion = data['TARGET'].corr(data['trackdone_spree'])
print(f"Correlación: {correlacion:.4f}")
# Out:
# Correlación: -0.2100
